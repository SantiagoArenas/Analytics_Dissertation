# %%
#%pip install fsspec huggingface_hub
# Out:
# ...
#   Obtaining dependency information for huggingface_hub from https://files.pythonhosted.org/packages/31/a0/651f93d154cb72323358bf2bbae3e642bdb5d2f1bfc874d096f7cb159fa0/huggingface_hub-0.35.3-py3-none-any.whl.metadata
#   Obtaining dependency information for huggingface_hub from https://files.pythonhosted.org/packages/31/a0/651f93d154cb72323358bf2bbae3e642bdb5d2f1bfc874d096f7cb159fa0/huggingface_hub-0.35.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/42/14/42b2651a2f46b022ccd948bca9f2d5af0fd8929c4eec235b8d6d844fbe67/filelock-3.19.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/42/14/42b2651a2f46b022ccd948bca9f2d5af0fd8929c4eec235b8d6d844fbe67/filelock-3.19.1-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd
import huggingface_hub

@article{dutang2020package,
  title={Package ‘casdatasets’},
  author={Dutang, Christophe and Charpentier, Arthur},
  journal={url: https://dutangc.perso.math.cnrs.fr/RRepository/pub/web/CASdatasets-manual.pdf},
  year={2020}
}

df = pd.read_csv("hf://datasets/mabilton/fremtpl2/freMTPL2freq.csv")
df.head()
# Out:
#    IDpol  ClaimNb  Exposure  VehPower  VehAge  DrivAge  BonusMalus VehBrand  \
# 0    1.0        1      0.10         5       0       55          50      B12
# 1    3.0        1      0.77         5       0       55          50      B12
# 2    5.0        1      0.75         6       2       52          50      B12
# 3   10.0        1      0.09         7       0       46          50      B12
# 4   11.0        1      0.84         7       0       46          50      B12
#
#     VehGas Area  Density       Region
# 0  Regular    D     1217  Rhone-Alpes
# 1  Regular    D     1217  Rhone-Alpes
# 2   Diesel    B       54     Picardie
# 3   Diesel    B       76    Aquitaine
# 4   Diesel    B       76    Aquitaine

# %%
df.to_csv("freMTPL2freq.csv", index=False)

# %%
df = pd.read_csv("hf://datasets/mabilton/fremtpl2/freMTPL2sev.csv")
df.head()
# Out:
#      IDpol  ClaimAmount
# 0     1552       995.20
# 1  1010996      1128.12
# 2  4024277      1851.11
# 3  4007252      1204.00
# 4  4046424      1204.00

# %%
df.to_csv("freMTPL2sev.csv", index=False)
